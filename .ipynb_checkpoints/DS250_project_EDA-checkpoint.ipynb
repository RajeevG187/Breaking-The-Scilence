# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
Attempt_to_commit_rape_I_V  = pd.read_csv('Rape_Data/Attempt_to_commit_rape_I_V.csv')
Attempt_to_commit_rape_I_V.head(4)
# Out:
#             State/UT  Attempt to Commit Rape (Total)(I)  \
# 0     Andhra Pradesh                                191
# 1  Arunachal Pradesh                                 11
# 2              Assam                                527
# 3              Bihar                                110
#
#    Attempt to Commit Rape (Total)(V)  A) Women (18 Yrs. And above)(I)  \
# 0                                192                              144
# 1                                 12                                5
# 2                                527                              525
# 3                                110                              105
#
#    A) Women (18 Yrs. And above)(I).1  B) Girls (Below 18 yrs))(I)  \
# 0                                144                           47
# 1                                  5                            6
# 2                                525                            2
# 3                                105                            5
#
#    B) Girls (Below 18 yrs))(I).1
# 0                             48
# 1                              7
# 2                              2
# 3                              5

# %%
CrimeAgainstWomen  = pd.read_csv('Rape_Data/CrimeAgainstWomen_Total_2016-18.csv')
CrimeAgainstWomen.head(5)
# Out:
#             State/UT   2016   2017   2018  \
# 0     Andhra Pradesh  16362  17909  16438
# 1  Arunachal Pradesh    367    337    368
# 2              Assam  20869  23082  27728
# 3              Bihar  13400  14711  16920
# 4       Chhattisgarh   5947   7996   8587
#
#    Percentage State Share To All-India (2018)  \
# 0                                         4.3
# 1                                         0.1
# 2                                         7.3
# 3                                         4.5
# 4                                         2.3
#
#    Mid-Year Projected Female Population (In Lakhs) (2018)+  \
# 0                                              260.0
# 1                                                7.2
# 2                                              167.0
# 3                                              567.4
# 4                                              141.9
#
#    Rate of Total Crime against Women (2018)++
# 0                                        63.2
# 1                                        51.1
# 2                                       166.0
# 3                                        29.8
# 4                                        60.5

# %% [markdown]
# **Q) Are there any consistent trends over these three years?**

# %%
data1= CrimeAgainstWomen[['State/UT','2016','2017','2018']]
sns.lineplot(data1,)
# Out:
# <Axes: >

# %%
data1.max()
# Out:
# State/UT    West Bengal
# 2016              49262
# 2017              56011
# 2018              59445
# dtype: object

# %% [markdown]
# We can observe that mostly the data remains same during the period 2016 2017 2018, and West Bengal tops all three years with maximum no. of Crime  against women

# %% [markdown]
# **Q) Are there regional patterns or clusters of higher or lower crime rates?(NSEW)**

# %%
CrimeAgainstWomen['Region'] = CrimeAgainstWomen['State/UT'].map(region_mapping)

vibrant_palette = sns.color_palette('husl', len(CrimeAgainstWomen['Region']))
fig, axes = plt.subplots(1, 3, figsize=(12, 8))
sns.barplot(CrimeAgainstWomen, x="Region", y="2016", ax=axes[0], palette=custom_palette)
axes[0].set_title("Region v.s 2016")
sns.barplot(CrimeAgainstWomen, x="Region", y="2017", ax=axes[1], palette=custom_palette)
axes[1].set_title("Region v.s 2017")
sns.barplot(CrimeAgainstWomen, x="Region", y="2018", ax=axes[2], palette=custom_palette)
axes[2].set_title("Region v.s 2018")
# Out:
# Text(0.5, 1.0, 'Region v.s 2018')

# %% [markdown]
# **Q) How do changes in population relate to changes in crime rates?(population data for each state for 2016-17-18)**(Vedant bhai)

# %%
Disposal_CrimeHead_Wise_2018 =pd.read_csv('Rape_Data/Disposal(CrimeHead-Wise)-2018.csv')
Disposal_CrimeHead_Wise_2018.head(4)
# Out:
#                  Crime Head  Persons Arrested Male  Persons Arrested Female  \
# 0                         2                      3                        4
# 1   POCSO Act Section 4 & 6                  25641                      605
# 2  POCSO Act Section 8 & 10                  16980                      164
# 3                      Rape                  40225                      892
#
#    Persons Arrested Total  Persons Chargesheeted Male  \
# 0                       5                           6
# 1                   26246                       23673
# 2                   17144                       16005
# 3                   41117                       36737
#
#    Persons Chargesheeted Female  Persons Chargesheeted Total  \
# 0                             7                            8
# 1                           465                        24138
# 2                           131                        16136
# 3                           776                        37513
#
#    Persons Convicted Male  Persons Convicted Female  Persons Convicted Total  \
# 0                       9                        10                       11
# 1                    3037                        20                     3057
# 2                    1918                         8                     1926
# 3                    5921                        48                     5969
#
#    Persons Discharged Male  Persons Discharged Female  \
# 0                       12                         13
# 1                      356                          2
# 2                      144                          1
# 3                     1996                         26
#
#    Persons Discharged Total  Persons Acquitted Male  Persons Acquitted Female  \
# 0                        14                      15                        16
# 1                       358                    5333                        86
# 2                       145                    2581                        10
# 3                      2022                   14177                       214
#
#    Persons Acquitted Total
# 0                       17
# 1                     5419
# 2                     2591
# 3                    14391

# %%
Custodial_rape = pd.read_csv('Rape_Data/Custodial_rape.csv')
Custodial_rape.head(4)
# Out:
#             State/UT  Punishment for Rape (Sec.376 & 376(I)  \
# 0     Andhra Pradesh                                    578
# 1  Arunachal Pradesh                                     42
# 2              Assam                                   1476
# 3              Bihar                                    625
#
#    Rape in Custody (Total)  By Police Personnel (Sec.376(2) (a)  \
# 0                        6                                    3
# 1                        0                                    0
# 2                        1                                    1
# 3                        0                                    0
#
#    By Public Servant (Sec.376(2) (b)  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
#
#    By Member of Armed Forces (Sec.376(2) (c)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
#
#    By Management/Staff of Jail/Remand Home/Place of Custody (Sec.376(2)(d)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    By Management/ Staff of Hospital (Sec.376(2) (e)
# 0                                                 2
# 1                                                 0
# 2                                                 0
# 3                                                 0

# %%
Non_custodial_rape = pd.read_csv('Rape_Data/Non_custodial_rape.csv')
Non_custodial_rape.head(4)
# Out:
#             State/UT  Rape Other than Custodial (Total)  \
# 0     Andhra Pradesh                                297
# 1  Arunachal Pradesh                                 22
# 2              Assam                                148
# 3              Bihar                                 17
#
#    By Relative/Guardian/Teacher/person in position of trust (Sec.376(2) (f)  \
# 0                                                 19
# 1                                                  4
# 2                                                 90
# 3                                                 11
#
#    On Pregnant Women (Sec.376(2) (h)  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
#
#    On Women Below 16 years of age (Sec.376(2) (i)  \
# 0                                             108
# 1                                              15
# 2                                              10
# 3                                               0
#
#    On Women Incapable of giving Consent (Sec.376(2) (j)  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
#
#    By Persons in Control or Dominance over women (Sec.376(2) (k)  \
# 0                                                  1
# 1                                                  0
# 2                                                 43
# 3                                                  0
#
#    On Women with Mental or Physical disability (Sec.376(2)(l)  \
# 0                                                  9
# 1                                                  1
# 2                                                  0
# 3                                                  2
#
#    Endanger life of Women after Rape (Sec.376(2)(m)  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
#
#    Repeated Rape on same women (Sec.376(2)(n)  Other Custo- dial Rapes  \
# 0                                          79                       81
# 1                                           1                        0
# 2                                           0                        5
# 3                                           1                        3
#
#    Punishment upto 20 years extended to life for Rape (Below 16 Yrs) (Sec.376(3))  \
# 0                                                 59
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    Punishment for causing Death (Sec.376(A))
# 0                                          1
# 1                                          0
# 2                                          0
# 3                                          0

# %%
data = pd.merge(Custodial_rape[["State/UT","Rape in Custody (Total)"]], Non_custodial_rape[["State/UT","Rape Other than Custodial (Total)"]], on='State/UT')
data['Normalized_Value_Rape in Custody (Total)'] = abs((data['Rape in Custody (Total)'] - data['Rape in Custody (Total)'].mean()) / data['Rape in Custody (Total)'].std())
data['Normalized_Value_Rape Other than Custodial (Total)'] = abs((data['Rape Other than Custodial (Total)'] - data['Rape Other than Custodial (Total)'].mean()) / data['Rape Other than Custodial (Total)'].std())
plt.figure(figsize=(8, 6))
data.plot.scatter(x='Normalized_Value_Rape in Custody (Total)', y='Normalized_Value_Rape Other than Custodial (Total)', c='blue', marker='o')
plt.title('Scatter Plot between Normalized Values')
plt.xlabel('Normalized_Value_Rape in Custody (Total)')
plt.ylabel('Normalized_Value_Rape Other than Custodial (Total)')
plt.show()
data
# Out:
#              State/UT  Rape in Custody (Total)  \
# 0      Andhra Pradesh                        6
# 1   Arunachal Pradesh                        0
# 2               Assam                        1
# 3               Bihar                        0
# 4        Chhattisgarh                        3
# 5                 Goa                        0
# 6             Gujarat                        1
# 7             Haryana                        0
# 8    Himachal Pradesh                        0
# 9     Jammu & Kashmir                        0
# 10          Jharkhand                        0
# 11          Karnataka                        0
# 12             Kerala                        0
# 13     Madhya Pradesh                       23
# 14        Maharashtra                        1
# 15            Manipur                        1
# 16          Meghalaya                        1
# 17            Mizoram                        0
# 18           Nagaland                        0
# 19             Odisha                        0
# 20             Punjab                        1
# 21          Rajasthan                        4
# 22             Sikkim                        0
# 23         Tamil Nadu                        1
# 24          Telangana                        0
# 25            Tripura                        0
# 26      Uttar Pradesh                       11
# 27        Uttarakhand                        0
# 28        West Bengal                        0
# 29        A&N Islands                        1
# 30         Chandigarh                        3
# 31         D&N Haveli                        0
# 32        Daman & Diu                        0
# 33              Delhi                        2
# 34        Lakshadweep                        0
# 35         Puducherry                        0
#
#     Rape Other than Custodial (Total)  \
# 0                                 297
# 1                                  22
# 2                                 148
# 3                                  17
# 4                                 743
# 5                                   3
# 6                                  47
# 7                                 196
# 8                                  71
# 9                                  65
# 10                                110
# 11                                 44
# 12                                645
# 13                               2314
# 14                                471
# 15                                 11
# 16                                 27
# 17                                  4
# 18                                  1
# 19                                426
# 20                                 43
# 21                                765
# 22                                  0
# 23                                  7
# 24                                114
# 25                                  1
# 26                                121
# 27                                232
# 28                                 12
# 29                                  1
# 30                                 17
# 31                                  0
# 32                                  1
# 33                                 26
# 34                                  0
# 35                                  0
#
#     Normalized_Value_Rape in Custody (Total)  \
# 0                                   1.019759
# 1                                   0.392215
# 2                                   0.156886
# 3                                   0.392215
# 4                                   0.313772
# 5                                   0.392215
# 6                                   0.156886
# 7                                   0.392215
# 8                                   0.392215
# 9                                   0.392215
# 10                                  0.392215
# 11                                  0.392215
# 12                                  0.392215
# 13                                  5.020352
# 14                                  0.156886
# 15                                  0.156886
# 16                                  0.156886
# 17                                  0.392215
# 18                                  0.392215
# 19                                  0.392215
# 20                                  0.156886
# 21                                  0.549101
# 22                                  0.392215
# 23                                  0.156886
# 24                                  0.392215
# 25                                  0.392215
# 26                                  2.196404
# 27                                  0.392215
# 28                                  0.392215
# 29                                  0.156886
# 30                                  0.313772
# 31                                  0.392215
# 32                                  0.392215
# 33                                  0.078443
# 34                                  0.392215
# 35                                  0.392215
#
#     Normalized_Value_Rape Other than Custodial (Total)
# 0                                            0.243349
# 1                                            0.409539
# 2                                            0.110398
# 3                                            0.421410
# 4                                            1.302216
# 5                                            0.454648
# 6                                            0.350186
# 7                                            0.003561
# 8                                            0.293206
# 9                                            0.307451
# 10                                           0.200615
# 11                                           0.357308
# 12                                           1.069550
# 13                                           5.031989
# 14                                           0.656450
# 15                                           0.435655
# 16                                           0.397668
# 17                                           0.452274
# 18                                           0.459396
# 19                                           0.549613
# 20                                           0.359682
# 21                                           1.354447
# 22                                           0.461770
# 23                                           0.445151
# 24                                           0.191118
# 25                                           0.459396
# 26                                           0.174499
# 27                                           0.089030
# 28                                           0.433281
# 29                                           0.459396
# 30                                           0.421410
# 31                                           0.461770
# 32                                           0.459396
# 33                                           0.400043
# 34                                           0.461770
# 35                                           0.461770

# %%
# pie_data=pd.merge(Custodial_rape[['State/UT','By Police Personnel (Sec.376(2) (a)','By Public Servant (Sec.376(2) (b)','By Member of Armed Forces (Sec.376(2) (c)']],Non_custodial_rape[['State/UT','By Relative/Guardian/Teacher/person in position of trust (Sec.376(2) (f)','On Pregnant Women (Sec.376(2) (h)','On Women Below 16 years of age (Sec.376(2) (i)','On Women Incapable of giving Consent (Sec.376(2) (j)']], on='State/UT')
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
pie_data1=Non_custodial_rape[['By Relative/Guardian/Teacher/person in position of trust (Sec.376(2) (f)','On Pregnant Women (Sec.376(2) (h)','On Women Below 16 years of age (Sec.376(2) (i)','On Women Incapable of giving Consent (Sec.376(2) (j)']]
pie_data2=Custodial_rape[['By Police Personnel (Sec.376(2) (a)','By Public Servant (Sec.376(2) (b)','By Member of Armed Forces (Sec.376(2) (c)']]
custom_palette = sns.color_palette("Set2", len(pie_data))
plt.figure(figsize=(8, 8))
axes[0].pie(pie_data1.sum(),autopct='%1.1f%%', startangle=90,colors=custom_palette)
axes[0].set_title('Pie Chart of Non Custodial Rape by Category')
axes[1].pie(pie_data2.sum(),autopct='%1.1f%%', startangle=90,colors=custom_palette)
axes[1].set_title('Pie Chart of Custodial Rape by Category')
plt.tight_layout() 
plt.show()

# %%
Non_custodial_rape['Region'] = Non_custodial_rape['State/UT'].map(region_mapping)

vibrant_palette = sns.color_palette('husl', len(Non_custodial_rape['Region']))
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.barplot(Non_custodial_rape, x="Region", y="By Relative/Guardian/Teacher/person in position of trust (Sec.376(2) (f)", ax=axes[0,0], palette=custom_palette)
axes[0,0].set_title("Region v.s By Relative/Guardian/Teacher (Sec.376(2) (f)")
sns.barplot(Non_custodial_rape, x="Region", y="On Women Below 16 years of age (Sec.376(2) (i)", ax=axes[0,1], palette=custom_palette)
axes[0,1].set_title("Region v.s On Women Below 16 years of age (Sec.376(2) (i)")
sns.barplot(Non_custodial_rape, x="Region", y="Repeated Rape on same women (Sec.376(2)(n)", ax=axes[1,0], palette=custom_palette)
axes[1,0].set_title("Region v.s Repeated Rape on same women (Sec.376(2)(n)")
sns.barplot(Non_custodial_rape, x="Region", y="On Women with Mental or Physical disability (Sec.376(2)(l)", ax=axes[1,1], palette=custom_palette)
axes[1,1].set_title("Region v.s On Women with Mental or Physical disability (Sec.376(2)(l)")
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1, wspace=0.4, hspace=0.4)

# %%
Police_Disposal_CrimeHead_Wise_2018 = pd.read_csv('Rape_Data/Police_Disposal(CrimeHead-Wise)-2018.csv')
Police_Disposal_CrimeHead_Wise_2018.head(5)
# Out:
#                    Crime Head  Cases Pending Investigation from Previous Year  \
# 0                           2                                               3
# 1     POCSO Act Section 4 & 6                                            7761
# 2    POCSO Act Section 8 & 10                                            5507
# 3                        Rape                                           13762
# 4  Murder with Rape/Gang Rape                                              99
#
#    Cases Reported during the year  Cases Reopened for Investigation  \
# 0                               4                                 5
# 1                           21401                                 2
# 2                           14124                                10
# 3                           33356                                21
# 4                             294                                 0
#
#    Total Cases for Investigation   Cases Not Investigated Under 157_1_b CRPC  \
# 0                               6                                          7
# 1                           29164                                          1
# 2                           19641                                          0
# 3                           47139                                          1
# 4                             393                                          0
#
#    Cases True but Insufficient Evidence or Untraced or No Clue  \
# 0                                                 13
# 1                                                360
# 2                                                294
# 3                                               1093
# 4                                                 24
#
#    Cases Abated during Investigation  Total   \
# 0                                 14      15
# 1                                 42     817
# 2                                  5     774
# 3                                 75    4841
# 4                                  2      33
#
#    Cases Charge_sheeted Out of Cases from Previous Year  \
# 0                                                 16
# 1                                               4538
# 2                                               2845
# 3                                               7054
# 4                                                 31
#
#    Cases Charge_sheeted Out of Cases during the Year  Cases Charge_sheeted
# 0                                                 17                    18
# 1                                              15006                 19544
# 2                                               9652                 12497
# 3                                              21415                 28469
# 4                                                193                   224

# %%
punished_rapists = pd.read_csv('Rape_Data/punished_rapists.csv')
punished_rapists.head(5)
# Out:
#             State/UT  By Seperated husband (Sec.376 (B))  \
# 0     Andhra Pradesh                                   0
# 1  Arunachal Pradesh                                   0
# 2              Assam                                   2
# 3              Bihar                                   0
# 4       Chhattisgarh                                   0
#
#    Rape/Gang Rape of Girl Below 16 Yrs (Imprisonment for life till death) (Sec.376(DA))  \
# 0                                                 13
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                 14
#
#    By Person in Authority (Sec.376 (C))  Gang Rape (Sec.376(D))  \
# 0                                     1                      12
# 1                                     0                       1
# 2                                     0                      20
# 3                                     0                       8
# 4                                     1                      38
#
#    Rape/Gang Rape of Girl Below 12 Yrs (Imprisonment for life till death) (Sec.376(DB))  \
# 0                                                  0
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    Rape/Gang Rape of Girl Below 16 Yrs (Imprisonment for life till death) (Sec.376(DB))  \
# 0                                                  4
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                 10
#
#    Punishment for Repeat offenders (Sec.376(E))  Rape (Total) (Sec.376 IPC)
# 0                                             0                         971
# 1                                             0                          67
# 2                                             0                        1648
# 3                                             0                         651
# 4                                             6                        2091

# %%
Rape_under_Different_age_groups_2018 = pd.read_csv('Rape_Data/Rape_under_Different_age_groups_2018.csv')
Rape_under_Different_age_groups_2018.head(5)
# Out:
#            State/UT   Cases Reported   Below 6 Years   \
# 0    Andhra Pradesh               971              16
# 1  Arunachal Pradesh               67               4
# 2             Assam              1648               7
# 3             Bihar               651               0
# 4      Chhattisgarh              2091              41
#
#    6 Years & Above (Below 12 Years)   12 Years & Above(Below 16 Years)  \
# 0                                 57                               181
# 1                                  4                                13
# 2                                 24                                 6
# 3                                  0                                 1
# 4                                 80                               557
#
#    16 Years & Above(Below 18 Years )  Total Girl /Child Victims(Below 18)  \
# 0                                251                                  505
# 1                                 11                                   32
# 2                                 52                                   89
# 3                                  3                                    4
# 4                                541                                 1219
#
#    18 Years & Above( Below 30 Years )  30 Years & Above (Below 45 Years)  \
# 0                                 373                                 76
# 1                                  29                                  9
# 2                                1043                                523
# 3                                 520                                111
# 4                                 644                                190
#
#    45 Years & Above(Below 60 Years)  60 Years & Above   \
# 0                                14                  5
# 1                                 0                  0
# 2                               107                  5
# 3                                16                  0
# 4                                42                  6
#
#    Total Women / Adult Victims(Above 18)  Total Victims
# 0                                    468             973
# 1                                     38              70
# 2                                   1678            1767
# 3                                    647             651
# 4                                    882            2101

# %%
RapeCommited_I_V =pd.read_csv('Rape_Data/RapeCommited_I_V.csv')
RapeCommited_I_V.head(5)
# Out:
#             State/UT  Rape (Total)(I)  Rape (Total)(V)  \
# 0     Andhra Pradesh              971              973
# 1  Arunachal Pradesh               67               70
# 2              Assam             1648             1767
# 3              Bihar              651              651
# 4       Chhattisgarh             2091             2101
#
#    Women (18 Yrs. And above)(I)   Women (18 Yrs. And above)(V)  \
# 0                           468                            468
# 1                            38                             38
# 2                          1559                           1678
# 3                           647                            647
# 4                           876                            882
#
#    Girls (Below 18 yrs)(I)  Girls (Below 18 yrs)(V)
# 0                      503                      505
# 1                       29                       32
# 2                       89                       89
# 3                        4                        4
# 4                     1215                     1219

# %% [markdown]
# **Q) What is the difference between "Rape (Total)(I)" and "Rape (Total)(V)"? How do these two categories relate to each other?**

# %% [markdown]
# I siginifies the no. of incidents and V means no.of victims.

# %%
data=RapeCommited_I_V[["State/UT","Rape (Total)(I)","Rape (Total)(V)"]].sort_values('Rape (Total)(V)',ascending=False).set_index('State/UT')
plt.figure(figsize=(8, 6))
sns.heatmap(data, annot=True, cmap='YlGnBu', fmt='g',)
plt.title('Heatmap of States v/s ')
plt.show()

# %%
data=RapeCommited_I_V.drop(columns=["Rape (Total)(I)","Rape (Total)(V)"]).sum()
data=data.to_frame()
data=data.iloc[1:]
sns.barplot(data.transpose(),)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# As We can see the total no. of victims is greater than total no. of incidences. Hence in each incident no. of vicims were >= 1.
# And no. of (18 yrs And Above) 2.5 times the (Below 18 yrs).

# %%
Rapist_Victim_relation  = pd.read_csv('Rape_Data/Rapist_Victim_relation.csv')
Rapist_Victim_relation.head(5)
# Out:
#              State/UT  Cases Offender known to Victim (Total)  Family members  \
# 0     Andhra Pradesh                                      912              64
# 1  Arunachal Pradesh                                       63              11
# 2              Assam                                     1488             141
# 3              Bihar                                      639               7
# 4       Chhattisgarh                                     1915             136
#
#    Family Friends/ Neighbours/ Employer or Other Known Persons  \
# 0                                                474
# 1                                                 33
# 2                                                784
# 3                                                219
# 4                                                796
#
#    Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband  \
# 0                                                374
# 1                                                 19
# 2                                                563
# 3                                                413
# 4                                                983
#
#    Cases Offenders Unknown or Not Identified  \
# 0                                         59
# 1                                          4
# 2                                        160
# 3                                         12
# 4                                        176
#
#    Total Rape Cases (Known+unknown Offenders)  \
# 0                                         971
# 1                                          67
# 2                                        1648
# 3                                         651
# 4                                        2091
#
#   Percentage Share of Known Cases to Total Rape Cases
# 0                                               93.9
# 1                                                 94
# 2                                               90.3
# 3                                               98.2
# 4                                               91.6

# %%
central_india = ['Madhya Pradesh ', 'Chhattisgarh ']
west_india = ['Rajasthan ', 'Gujarat ', 'Maharashtra ', 'Goa ']
east_india = ['Bihar ', 'Jharkhand ', 'Odisha ', 'West Bengal ', 'Sikkim ', 'Assam ', 'Arunachal Pradesh ', 'Nagaland ', 'Manipur ', 'Mizoram ', 'Tripura ', 'Meghalaya']
south_india = ['Andhra Pradesh ', 'Telangana ', 'Karnataka ', 'Tamil Nadu ', 'Kerala ']
north_india = ['Jammu & Kashmir ', 'Himachal Pradesh ', 'Punjab ', 'Haryana ', 'Uttarakhand ', 'Uttar Pradesh ', 'Delhi UT ']
for i in range(len(central_india)):
    central_india[i]=central_india[i].strip()
for i in range(len(west_india)):
    west_india[i]=west_india[i].strip()
for i in range(len(east_india)):
    east_india[i]=east_india[i].strip()
for i in range(len(south_india)):
    south_india[i]=south_india[i].strip()
for i in range(len(north_india)):
    north_india[i]=north_india[i].strip()

# %%
states= Rapist_Victim_relation["State/UT"].tolist()
for i in range(len(states)):
    states[i]=states[i].strip()
states
Rapist_Victim_relation["State/UT"]=pd.Series(states)

# %%
Rapist_Victim_relation.shape
# Out:
# (36, 8)

# %%
Rapist_Victim_relation.columns
# Out:
# Index(['State/UT ', 'Cases Offender known to Victim (Total)', 'Family members',
#        'Family Friends/ Neighbours/ Employer or Other Known Persons',
#        'Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband',
#        'Cases Offenders Unknown or Not Identified',
#        'Total Rape Cases (Known+unknown Offenders)',
#        'Percentage Share of Known Cases to Total Rape Cases '],
#       dtype='object')

# %%
Rapist_Victim_relation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   State/UT                                                                             36 non-null     object
#  1   Cases Offender known to Victim (Total)                                               36 non-null     int64
#  2   Family members                                                                       36 non-null     int64
#  3   Family Friends/ Neighbours/ Employer or Other Known Persons                          36 non-null     int64
#  4   Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband  36 non-null     int64
#  5   Cases Offenders Unknown or Not Identified                                            36 non-null     int64
#  6   Total Rape Cases (Known+unknown Offenders)                                           36 non-null     int64
#  7   Percentage Share of Known Cases to Total Rape Cases                                  36 non-null     object
# dtypes: int64(6), object(2)
# memory usage: 2.4+ KB

# %%
Rapist_Victim_relation.describe()
# Out:
#        Cases Offender known to Victim (Total)  Family members  \
# count                               36.000000       36.000000
# mean                               870.000000       77.222222
# std                               1205.161661      117.658856
# min                                  0.000000        0.000000
# 25%                                 55.250000        4.000000
# 50%                                455.500000       20.000000
# 75%                               1059.750000      122.750000
# max                               5209.000000      553.000000
#
#        Family Friends/ Neighbours/ Employer or Other Known Persons  \
# count                                          36.000000
# mean                                          443.666667
# std                                           637.630300
# min                                             0.000000
# 25%                                            30.000000
# 50%                                           205.500000
# 75%                                           567.750000
# max                                          2543.000000
#
#        Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband  \
# count                                          36.000000
# mean                                          349.111111
# std                                           483.048875
# min                                             0.000000
# 25%                                            18.250000
# 50%                                           144.000000
# 75%                                           449.750000
# max                                          2113.000000
#
#        Cases Offenders Unknown or Not Identified  \
# count                                  36.000000
# mean                                   56.555556
# std                                   111.734493
# min                                     0.000000
# 25%                                     2.750000
# 50%                                     8.000000
# 75%                                    59.250000
# max                                   587.000000
#
#        Total Rape Cases (Known+unknown Offenders)
# count                                   36.000000
# mean                                   926.555556
# std                                   1291.949567
# min                                      0.000000
# 25%                                     58.750000
# 50%                                    522.500000
# 75%                                   1121.250000
# max                                   5433.000000

# %%
Q1 = Rapist_Victim_relation['Total Rape Cases (Known+unknown Offenders)'].quantile(0.25)
Q3 = Rapist_Victim_relation['Total Rape Cases (Known+unknown Offenders)'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = (Rapist_Victim_relation['Total Rape Cases (Known+unknown Offenders)'] < lower_bound) | (Rapist_Victim_relation['Total Rape Cases (Known+unknown Offenders)'] > upper_bound)
Rapist_Victim_relation[outliers].sort_values(by='Total Rape Cases (Known+unknown Offenders)', ascending=False)
# Out:
#           State/UT   Cases Offender known to Victim (Total)  Family members  \
# 13  Madhya Pradesh                                     5209             553
# 21       Rajasthan                                     3748             298
# 26   Uttar Pradesh                                     3718             287
#
#     Family Friends/ Neighbours/ Employer or Other Known Persons  \
# 13                                               2543
# 21                                               2193
# 26                                               2121
#
#     Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband  \
# 13                                               2113
# 21                                               1257
# 26                                               1310
#
#     Cases Offenders Unknown or Not Identified  \
# 13                                        224
# 21                                        587
# 26                                        228
#
#     Total Rape Cases (Known+unknown Offenders)  \
# 13                                        5433
# 21                                        4335
# 26                                        3946
#
#    Percentage Share of Known Cases to Total Rape Cases
# 13                                               95.9
# 21                                               86.5
# 26                                               94.2

# %% [markdown]
# **Q) Are there any trends or patterns in the cases involving family friends, neighbors, employers, or other known persons?**

# %%
data = Rapist_Victim_relation.sort_values(by="Cases Offender known to Victim (Total)", ascending=False)
data = data.head(5)
data= data[['State/UT', 'Cases Offender known to Victim (Total)', 'Family Friends/ Neighbours/ Employer or Other Known Persons','Family members']]
melted_data = pd.melt(data, id_vars=['State/UT'], var_name='Attribute', value_name='Value')

vibrant_palette = sns.color_palette('husl', len(data['State/UT']))

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='State/UT', y='Value', hue='Attribute', data=melted_data, palette=vibrant_palette)
plt.title('Top 5 States - Known Victims Comparison')
plt.ylabel('Value')
plt.xlabel('State')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Relation with Victim')
plt.show()

# %%
percentage_data = pd.DataFrame()

# Calculate the percentages
new_data = Rapist_Victim_relation.sort_values(by="Cases Offender known to Victim (Total)", ascending=False)
percentage_data['State/UT'] = new_data['State/UT']
percentage_data['Family Members Percentage'] = (new_data['Family members'] / new_data['Cases Offender known to Victim (Total)']) * 100
percentage_data['Family Friends Percentage'] = (new_data['Family Friends/ Neighbours/ Employer or Other Known Persons'] / new_data['Cases Offender known to Victim (Total)']) * 100
percentage_data['Total Percentage'] = ((new_data['Family members']+new_data['Family Friends/ Neighbours/ Employer or Other Known Persons'])/new_data['Cases Offender known to Victim (Total)']) * 100
percentage_data
# Out:
#              State/UT  Family Members Percentage  Family Friends Percentage  \
# 13     Madhya Pradesh                  10.616241                  48.819351
# 21          Rajasthan                   7.950907                  58.511206
# 26      Uttar Pradesh                   7.719204                  57.046799
# 14        Maharashtra                   7.438795                  46.657250
# 4        Chhattisgarh                   7.101828                  41.566580
# 12             Kerala                  14.733542                  39.341693
# 2               Assam                   9.475806                  52.688172
# 7             Haryana                  11.974110                  60.194175
# 33           Delhi UT                  10.469012                  42.629816
# 10          Jharkhand                  12.019704                  49.950739
# 28        West Bengal                   2.505219                  89.979123
# 0      Andhra Pradesh                   7.017544                  51.973684
# 19             Odisha                   0.110988                  13.207547
# 20             Punjab                   7.177616                  59.002433
# 3               Bihar                   1.095462                  34.272300
# 24          Telangana                  14.023372                  41.068447
# 6             Gujarat                  11.090226                  47.932331
# 11          Karnataka                  12.090164                  56.557377
# 27        Uttarakhand                   0.945626                  81.560284
# 8    Himachal Pradesh                  12.684366                  47.492625
# 23         Tamil Nadu                  13.761468                  37.308869
# 9     Jammu & Kashmir                   5.054152                  69.314079
# 25            Tripura                   5.319149                  60.638298
# 30         Chandigarh                   5.952381                  46.428571
# 16          Meghalaya                  19.753086                  71.604938
# 1   Arunachal Pradesh                  17.460317                  52.380952
# 5                 Goa                   8.771930                  36.842105
# 15            Manipur                   8.000000                  24.000000
# 17            Mizoram                  24.489796                  67.346939
# 29      A & N Islands                  14.814815                  25.925926
# 22             Sikkim                  12.500000                  37.500000
# 18           Nagaland                  10.000000                  70.000000
# 31         D&N Haveli                  28.571429                  14.285714
# 32        Daman & Diu                   0.000000                   0.000000
# 34        Lakshadweep                   0.000000                  50.000000
# 35         Puducherry                        NaN                        NaN
#
#     Total Percentage
# 13         59.435592
# 21         66.462113
# 26         64.766003
# 14         54.096045
# 4          48.668407
# 12         54.075235
# 2          62.163978
# 7          72.168285
# 33         53.098827
# 10         61.970443
# 28         92.484342
# 0          58.991228
# 19         13.318535
# 20         66.180049
# 3          35.367762
# 24         55.091820
# 6          59.022556
# 11         68.647541
# 27         82.505910
# 8          60.176991
# 23         51.070336
# 9          74.368231
# 25         65.957447
# 30         52.380952
# 16         91.358025
# 1          69.841270
# 5          45.614035
# 15         32.000000
# 17         91.836735
# 29         40.740741
# 22         50.000000
# 18         80.000000
# 31         42.857143
# 32          0.000000
# 34         50.000000
# 35               NaN

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Family Friends Percentage', y='Total Percentage', data=percentage_data, hue='State/UT', palette='viridis', s=100)
plt.title('Relationship Between Family Friends Percentage and Total Percentage')
plt.xlabel('Family Friends Percentage')
plt.ylabel('Total Percentage')
plt.legend(title='State/UT', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# #Display On the spot#
# From this Plot we can see that that family friends percentage is linearly related to total known percentage linearly.

# %% [markdown]
# **What is the percentage share of known offenders compared to cases where the offender is unknown or not identified?**

# %%
new_data.columns
# Out:
# Index(['State/UT', 'Cases Offender known to Victim (Total)', 'Family members',
#        'Family Friends/ Neighbours/ Employer or Other Known Persons',
#        'Friends/Online-Friends or Live in Partners on Pretext of Marriage/Seperated Husband',
#        'Cases Offenders Unknown or Not Identified',
#        'Total Rape Cases (Known+unknown Offenders)',
#        'Percentage Share of Known Cases to Total Rape Cases '],
#       dtype='object')

# %%
percentage_data['Known Offenders'] = (new_data['Cases Offender known to Victim (Total)'] / new_data['Total Rape Cases (Known+unknown Offenders)']) * 100
percentage_data['Unknown Offenders'] = (new_data['Cases Offenders Unknown or Not Identified'] / new_data['Total Rape Cases (Known+unknown Offenders)']) * 100

# %%
percentage_data
# Out:
#              State/UT  Family Members Percentage  Family Friends Percentage  \
# 13     Madhya Pradesh                  10.616241                  48.819351
# 21          Rajasthan                   7.950907                  58.511206
# 26      Uttar Pradesh                   7.719204                  57.046799
# 14        Maharashtra                   7.438795                  46.657250
# 4        Chhattisgarh                   7.101828                  41.566580
# 12             Kerala                  14.733542                  39.341693
# 2               Assam                   9.475806                  52.688172
# 7             Haryana                  11.974110                  60.194175
# 33           Delhi UT                  10.469012                  42.629816
# 10          Jharkhand                  12.019704                  49.950739
# 28        West Bengal                   2.505219                  89.979123
# 0      Andhra Pradesh                   7.017544                  51.973684
# 19             Odisha                   0.110988                  13.207547
# 20             Punjab                   7.177616                  59.002433
# 3               Bihar                   1.095462                  34.272300
# 24          Telangana                  14.023372                  41.068447
# 6             Gujarat                  11.090226                  47.932331
# 11          Karnataka                  12.090164                  56.557377
# 27        Uttarakhand                   0.945626                  81.560284
# 8    Himachal Pradesh                  12.684366                  47.492625
# 23         Tamil Nadu                  13.761468                  37.308869
# 9     Jammu & Kashmir                   5.054152                  69.314079
# 25            Tripura                   5.319149                  60.638298
# 30         Chandigarh                   5.952381                  46.428571
# 16          Meghalaya                  19.753086                  71.604938
# 1   Arunachal Pradesh                  17.460317                  52.380952
# 5                 Goa                   8.771930                  36.842105
# 15            Manipur                   8.000000                  24.000000
# 17            Mizoram                  24.489796                  67.346939
# 29      A & N Islands                  14.814815                  25.925926
# 22             Sikkim                  12.500000                  37.500000
# 18           Nagaland                  10.000000                  70.000000
# 31         D&N Haveli                  28.571429                  14.285714
# 32        Daman & Diu                   0.000000                   0.000000
# 34        Lakshadweep                   0.000000                  50.000000
# 35         Puducherry                        NaN                        NaN
#
#     Total Percentage  Known Offenders  Unknown Offenders
# 13         59.435592        95.877048           4.122952
# 21         66.462113        86.459054          13.540946
# 26         64.766003        94.221997           5.778003
# 14         54.096045        99.159664           0.840336
# 4          48.668407        91.582975           8.417025
# 12         54.075235        98.406170           1.593830
# 2          62.163978        90.291262           9.708738
# 7          72.168285        95.370370           4.629630
# 33         53.098827        98.271605           1.728395
# 10         61.970443        93.119266           6.880734
# 28         92.484342        89.616464          10.383536
# 0          58.991228        93.923790           6.076210
# 19         13.318535        98.148148           1.851852
# 20         66.180049        98.916968           1.083032
# 3          35.367762        98.156682           1.843318
# 24         55.091820        98.844884           1.155116
# 6          59.022556        96.202532           3.797468
# 11         68.647541        99.186992           0.813008
# 27         82.505910        75.401070          24.598930
# 8          60.176991        98.546512           1.453488
# 23         51.070336        98.791541           1.208459
# 9          74.368231        86.562500          13.437500
# 25         65.957447        96.907216           3.092784
# 30         52.380952        97.674419           2.325581
# 16         91.358025        93.103448           6.896552
# 1          69.841270        94.029851           5.970149
# 5          45.614035        93.442623           6.557377
# 15         32.000000        96.153846           3.846154
# 17         91.836735        98.000000           2.000000
# 29         40.740741        90.000000          10.000000
# 22         50.000000       100.000000           0.000000
# 18         80.000000       100.000000           0.000000
# 31         42.857143       100.000000           0.000000
# 32          0.000000        66.666667          33.333333
# 34         50.000000       100.000000           0.000000
# 35               NaN              NaN                NaN

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cases Offender known to Victim (Total)', y='Cases Offenders Unknown or Not Identified', data=new_data, hue='State/UT', palette='viridis', s=100)
plt.title('Relationship Between Family Friends Percentage and Total Percentage')
plt.xlabel('Family Friends Percentage')
plt.ylabel('Total Percentage')
plt.legend(title='State/UT', bbox_to_anchor=(1, 1))
plt.show()

# %%
percentage_data
# Out:
#              State/UT  Family Members Percentage  Family Friends Percentage  \
# 13     Madhya Pradesh                  10.616241                  48.819351
# 21          Rajasthan                   7.950907                  58.511206
# 26      Uttar Pradesh                   7.719204                  57.046799
# 14        Maharashtra                   7.438795                  46.657250
# 4        Chhattisgarh                   7.101828                  41.566580
# 12             Kerala                  14.733542                  39.341693
# 2               Assam                   9.475806                  52.688172
# 7             Haryana                  11.974110                  60.194175
# 33           Delhi UT                  10.469012                  42.629816
# 10          Jharkhand                  12.019704                  49.950739
# 28        West Bengal                   2.505219                  89.979123
# 0      Andhra Pradesh                   7.017544                  51.973684
# 19             Odisha                   0.110988                  13.207547
# 20             Punjab                   7.177616                  59.002433
# 3               Bihar                   1.095462                  34.272300
# 24          Telangana                  14.023372                  41.068447
# 6             Gujarat                  11.090226                  47.932331
# 11          Karnataka                  12.090164                  56.557377
# 27        Uttarakhand                   0.945626                  81.560284
# 8    Himachal Pradesh                  12.684366                  47.492625
# 23         Tamil Nadu                  13.761468                  37.308869
# 9     Jammu & Kashmir                   5.054152                  69.314079
# 25            Tripura                   5.319149                  60.638298
# 30         Chandigarh                   5.952381                  46.428571
# 16          Meghalaya                  19.753086                  71.604938
# 1   Arunachal Pradesh                  17.460317                  52.380952
# 5                 Goa                   8.771930                  36.842105
# 15            Manipur                   8.000000                  24.000000
# 17            Mizoram                  24.489796                  67.346939
# 29      A & N Islands                  14.814815                  25.925926
# 22             Sikkim                  12.500000                  37.500000
# 18           Nagaland                  10.000000                  70.000000
# 31         D&N Haveli                  28.571429                  14.285714
# 32        Daman & Diu                   0.000000                   0.000000
# 34        Lakshadweep                   0.000000                  50.000000
# 35         Puducherry                        NaN                        NaN
#
#     Total Percentage  Known Offenders  Unknown Offenders
# 13         59.435592        95.877048           4.122952
# 21         66.462113        86.459054          13.540946
# 26         64.766003        94.221997           5.778003
# 14         54.096045        99.159664           0.840336
# 4          48.668407        91.582975           8.417025
# 12         54.075235        98.406170           1.593830
# 2          62.163978        90.291262           9.708738
# 7          72.168285        95.370370           4.629630
# 33         53.098827        98.271605           1.728395
# 10         61.970443        93.119266           6.880734
# 28         92.484342        89.616464          10.383536
# 0          58.991228        93.923790           6.076210
# 19         13.318535        98.148148           1.851852
# 20         66.180049        98.916968           1.083032
# 3          35.367762        98.156682           1.843318
# 24         55.091820        98.844884           1.155116
# 6          59.022556        96.202532           3.797468
# 11         68.647541        99.186992           0.813008
# 27         82.505910        75.401070          24.598930
# 8          60.176991        98.546512           1.453488
# 23         51.070336        98.791541           1.208459
# 9          74.368231        86.562500          13.437500
# 25         65.957447        96.907216           3.092784
# 30         52.380952        97.674419           2.325581
# 16         91.358025        93.103448           6.896552
# 1          69.841270        94.029851           5.970149
# 5          45.614035        93.442623           6.557377
# 15         32.000000        96.153846           3.846154
# 17         91.836735        98.000000           2.000000
# 29         40.740741        90.000000          10.000000
# 22         50.000000       100.000000           0.000000
# 18         80.000000       100.000000           0.000000
# 31         42.857143       100.000000           0.000000
# 32          0.000000        66.666667          33.333333
# 34         50.000000       100.000000           0.000000
# 35               NaN              NaN                NaN

# %%
region_mapping = {
    **{state: 'North' for state in north_india},
    **{state: 'South' for state in south_india},
    **{state: 'East' for state in east_india},
    **{state: 'West' for state in west_india},
    **{state: 'Central' for state in central_india}
}

percentage_data['Region'] = percentage_data['State/UT'].map(region_mapping)

# Create a cluster map
cluster_map = sns.clustermap(
    data=percentage_data[[ 'Known Offenders','Family Friends Percentage','Family Members Percentage']].head(30),
    col_cluster=False,
    row_cluster=True,
    cmap='viridis',
    method='average',
    figsize=(12, 8),
)

reordered_indices = cluster_map.dendrogram_row.reordered_ind
cluster_map.ax_row_dendrogram.set_yticks(range(len(reordered_indices)))
cluster_map.ax_row_dendrogram.set_yticklabels(percentage_data['Region'].iloc[reordered_indices], fontsize=8)


plt.title('Cluster Map of Percentage Data by Region')
plt.show()

# %% [markdown]
# **Is there a correlation between economic factors and the prevalence of different types of rape cases?**

# %%
percentage_data.dropna(inplace =True)

# %%
economy_data = pd.read_csv("Rape_Data/Economy_Data.csv")
economy_data
# Out:
#     Rank              State GDP per capita ($)
# 0      1                Goa              7,029
# 1      2             Sikkim              6,421
# 2      3              Delhi              5,817
# 3      4         Chandigarh              5,297
# 4      5            Haryana              3,840
# 5      6          Karnataka              3,359
# 6      7         Puducherry              3,334
# 7      8             Kerala              3,327
# 8      9          Telangana              3,321
# 9     10            Gujarat              3,283
# 10    11        Uttarakhand              3,250
# 11    12        Maharashtra              3,193
# 12    13         Tamil Nadu              3,184
# 13    14   Himachal Pradesh              3,118
# 14    15            Mizoram              2,773
# 15    16             Punjab              2,536
# 16    17     Andhra Pradesh              2,480
# 17    18  Arunachal Pradesh              2,253
# 18    19           Nagaland              1,918
# 19    20            Tripura              1,851
# 20    21          Rajasthan              1,820
# 21    22             Odisha              1,651
# 22    23    Jammu & Kashmir              1,636
# 23    24        West Bengal              1,634
# 24    25       Chhattisgarh              1,555
# 25    26     Madhya Pradesh              1,461
# 26    27          Meghalaya              1,417
# 27    28              Assam              1,365
# 28    29            Manipur              1,222
# 29    30          Jharkhand              1,179
# 30    31      Uttar Pradesh              1,043
# 31    32              Bihar                659

# %%
economy_data.rename(columns={"State":"State/UT"}, inplace=True)
economy_data["State/UT"].tolist()
# Out:
# ['Goa',
#  'Sikkim',
#  'Delhi',
#  'Chandigarh',
#  'Haryana',
#  'Karnataka',
#  'Puducherry',
#  'Kerala',
#  'Telangana',
#  'Gujarat',
#  'Uttarakhand',
#  'Maharashtra',
#  'Tamil Nadu',
#  'Himachal Pradesh',
#  'Mizoram',
#  'Punjab',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Nagaland',
#  'Tripura',
#  'Rajasthan',
#  'Odisha',
#  'Jammu & Kashmir',
#  'West Bengal',
#  'Chhattisgarh',
#  'Madhya Pradesh',
#  'Meghalaya',
#  'Assam',
#  'Manipur',
#  'Jharkhand',
#  'Uttar Pradesh',
#  'Bihar']

# %%
percentage_data.merge(economy_data, on='State/UT')
percentage_data
# Out:
#              State/UT  Family Members Percentage  Family Friends Percentage  \
# 13     Madhya Pradesh                  10.616241                  48.819351
# 21          Rajasthan                   7.950907                  58.511206
# 26      Uttar Pradesh                   7.719204                  57.046799
# 14        Maharashtra                   7.438795                  46.657250
# 4        Chhattisgarh                   7.101828                  41.566580
# 12             Kerala                  14.733542                  39.341693
# 2               Assam                   9.475806                  52.688172
# 7             Haryana                  11.974110                  60.194175
# 33           Delhi UT                  10.469012                  42.629816
# 10          Jharkhand                  12.019704                  49.950739
# 28        West Bengal                   2.505219                  89.979123
# 0      Andhra Pradesh                   7.017544                  51.973684
# 19             Odisha                   0.110988                  13.207547
# 20             Punjab                   7.177616                  59.002433
# 3               Bihar                   1.095462                  34.272300
# 24          Telangana                  14.023372                  41.068447
# 6             Gujarat                  11.090226                  47.932331
# 11          Karnataka                  12.090164                  56.557377
# 27        Uttarakhand                   0.945626                  81.560284
# 8    Himachal Pradesh                  12.684366                  47.492625
# 23         Tamil Nadu                  13.761468                  37.308869
# 9     Jammu & Kashmir                   5.054152                  69.314079
# 25            Tripura                   5.319149                  60.638298
# 16          Meghalaya                  19.753086                  71.604938
# 1   Arunachal Pradesh                  17.460317                  52.380952
# 5                 Goa                   8.771930                  36.842105
# 15            Manipur                   8.000000                  24.000000
# 17            Mizoram                  24.489796                  67.346939
# 22             Sikkim                  12.500000                  37.500000
# 18           Nagaland                  10.000000                  70.000000
#
#     Total Percentage  Known Offenders  Unknown Offenders   Region
# 13         59.435592        95.877048           4.122952  Central
# 21         66.462113        86.459054          13.540946     West
# 26         64.766003        94.221997           5.778003    North
# 14         54.096045        99.159664           0.840336     West
# 4          48.668407        91.582975           8.417025  Central
# 12         54.075235        98.406170           1.593830    South
# 2          62.163978        90.291262           9.708738     East
# 7          72.168285        95.370370           4.629630    North
# 33         53.098827        98.271605           1.728395    North
# 10         61.970443        93.119266           6.880734     East
# 28         92.484342        89.616464          10.383536     East
# 0          58.991228        93.923790           6.076210    South
# 19         13.318535        98.148148           1.851852     East
# 20         66.180049        98.916968           1.083032    North
# 3          35.367762        98.156682           1.843318     East
# 24         55.091820        98.844884           1.155116    South
# 6          59.022556        96.202532           3.797468     West
# 11         68.647541        99.186992           0.813008    South
# 27         82.505910        75.401070          24.598930    North
# 8          60.176991        98.546512           1.453488    North
# 23         51.070336        98.791541           1.208459    South
# 9          74.368231        86.562500          13.437500    North
# 25         65.957447        96.907216           3.092784     East
# 16         91.358025        93.103448           6.896552     East
# 1          69.841270        94.029851           5.970149     East
# 5          45.614035        93.442623           6.557377     West
# 15         32.000000        96.153846           3.846154     East
# 17         91.836735        98.000000           2.000000     East
# 22         50.000000       100.000000           0.000000     East
# 18         80.000000       100.000000           0.000000     East

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Total Percentage', y='GDP per capita ($)', hue='Region', data=percentage_data.merge(economy_data, on='State/UT'), palette='viridis', s=100)
plt.title('Comparison of Unknown Offenders and GDP per capita ($) by Region')
plt.xlabel('Unknown Offenders Percentage')
plt.ylabel('GDP per capita ($)')
plt.legend(title='Region', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Out:
#              State/UT  Family Members Percentage  Family Friends Percentage  \
# 0      Madhya Pradesh                  10.616241                  48.819351
# 1           Rajasthan                   7.950907                  58.511206
# 2       Uttar Pradesh                   7.719204                  57.046799
# 3         Maharashtra                   7.438795                  46.657250
# 4        Chhattisgarh                   7.101828                  41.566580
# 5              Kerala                  14.733542                  39.341693
# 6               Assam                   9.475806                  52.688172
# 7             Haryana                  11.974110                  60.194175
# 8           Jharkhand                  12.019704                  49.950739
# 9         West Bengal                   2.505219                  89.979123
# 10     Andhra Pradesh                   7.017544                  51.973684
# 11             Odisha                   0.110988                  13.207547
# 12             Punjab                   7.177616                  59.002433
# 13              Bihar                   1.095462                  34.272300
# 14          Telangana                  14.023372                  41.068447
# 15            Gujarat                  11.090226                  47.932331
# 16          Karnataka                  12.090164                  56.557377
# 17        Uttarakhand                   0.945626                  81.560284
# 18   Himachal Pradesh                  12.684366                  47.492625
# 19         Tamil Nadu                  13.761468                  37.308869
# 20    Jammu & Kashmir                   5.054152                  69.314079
# 21            Tripura                   5.319149                  60.638298
# 22          Meghalaya                  19.753086                  71.604938
# 23  Arunachal Pradesh                  17.460317                  52.380952
# 24                Goa                   8.771930                  36.842105
# 25            Manipur                   8.000000                  24.000000
# 26            Mizoram                  24.489796                  67.346939
# 27             Sikkim                  12.500000                  37.500000
# 28           Nagaland                  10.000000                  70.000000
#
#     Total Percentage  Known Offenders  Unknown Offenders   Region  Rank  \
# 0          59.435592        95.877048           4.122952  Central    26
# 1          66.462113        86.459054          13.540946     West    21
# 2          64.766003        94.221997           5.778003    North    31
# 3          54.096045        99.159664           0.840336     West    12
# 4          48.668407        91.582975           8.417025  Central    25
# 5          54.075235        98.406170           1.593830    South     8
# 6          62.163978        90.291262           9.708738     East    28
# 7          72.168285        95.370370           4.629630    North     5
# 8          61.970443        93.119266           6.880734     East    30
# 9          92.484342        89.616464          10.383536     East    24
# 10         58.991228        93.923790           6.076210    South    17
# 11         13.318535        98.148148           1.851852     East    22
# 12         66.180049        98.916968           1.083032    North    16
# 13         35.367762        98.156682           1.843318     East    32
# 14         55.091820        98.844884           1.155116    South     9
# 15         59.022556        96.202532           3.797468     West    10
# 16         68.647541        99.186992           0.813008    South     6
# 17         82.505910        75.401070          24.598930    North    11
# 18         60.176991        98.546512           1.453488    North    14
# 19         51.070336        98.791541           1.208459    South    13
# 20         74.368231        86.562500          13.437500    North    23
# 21         65.957447        96.907216           3.092784     East    20
# 22         91.358025        93.103448           6.896552     East    27
# 23         69.841270        94.029851           5.970149     East    18
# 24         45.614035        93.442623           6.557377     West     1
# 25         32.000000        96.153846           3.846154     East    29
# 26         91.836735        98.000000           2.000000     East    15
# 27         50.000000       100.000000           0.000000     East     2
# 28         80.000000       100.000000           0.000000     East    19
#
#    GDP per capita ($)
# 0               1,461
# 1               1,820
# 2               1,043
# 3               3,193
# 4               1,555
# 5               3,327
# 6               1,365
# 7               3,840
# 8               1,179
# 9               1,634
# 10              2,480
# 11              1,651
# 12              2,536
# 13                659
# 14              3,321
# 15              3,283
# 16              3,359
# 17              3,250
# 18              3,118
# 19              3,184
# 20              1,636
# 21              1,851
# 22              1,417
# 23              2,253
# 24              7,029
# 25              1,222
# 26              2,773
# 27              6,421
# 28              1,918
